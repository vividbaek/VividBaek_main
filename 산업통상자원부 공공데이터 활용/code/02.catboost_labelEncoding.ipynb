# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer
from category_encoders import BinaryEncoder
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import xgboost as xgb
import lightgbm as lgb
from sklearn.metrics import accuracy_score


font_path = '../Font/GmarketSansTTFMedium.ttf'
font_name = fm.FontProperties(fname=font_path).get_name()
plt.rc('font', family=font_name)

plt.rcParams['axes.unicode_minus'] = False

# %%
seoul = pd.read_csv('../Data/preprocessing/seoul_real_transcation_price.csv')

# %%
seoul.head(5)
# Out:
#      시도명 시군구명       관리기관          회사명 공장구분 단지명 설립구분  입주형태 보유구분  등록구분  ...  \
# 0  서울특별시  종로구  서울특별시 종로구     남일문화 (주)   개별       일반  해당없음   임대  신규등록  ...
# 1  서울특별시  종로구  서울특별시 종로구    (주)에취.알.디   개별       일반  해당없음   임대  등록변경  ...
# 2  서울특별시  종로구  서울특별시 종로구  (주)코리아쉬핑가제트   개별       일반  해당없음   자가  등록변경  ...
# 3  서울특별시  종로구  서울특별시 종로구         삼영DP   개별       일반  해당없음   임대  신규등록  ...
# 4  서울특별시  종로구  서울특별시 종로구         삼진기획   개별       일반  해당없음   임대  등록변경  ...
#
#   지식산업센터명   대표업종              업종명                        업종코드  차수  \
# 0          18111      경 인쇄업 외 2 종         181,111,811,318,119  10
# 1          33932       전시용 모형 제조업                       33932  10
# 2          58113  일반 서적 출판업 외 3 종  58,113,181,111,811,300,000  10
# 3          18111      경 인쇄업 외 2 종         181,111,811,318,119  10
# 4          18119     기타 인쇄업 외 1 종               1,811,918,113  10
#
#                                     법인주소 필지수                         공장주소  \
# 0              서울특별시 종로구 자하문로16길 8 (창성동)   1    서울특별시 종로구 자하문로16길 8 (창성동)
# 1                  서울특별시 종로구 통의동 35-69번지   1        서울특별시 종로구 통의동 35-69번지
# 2   서울특별시 도봉구 창동 181-17번지 쌍용아파트 115-1902   1  서울특별시 종로구 자하문로2길 13-3 (통의동)
# 3                서울특별시 종로구 사직로 125 (적선동)   1      서울특별시 종로구 사직로 125 (적선동)
# 4  서울특별시 서대문구 홍제동 -번지 문화촌현대아파트 103-1101호   1            서울특별시 종로구 적선동 2번지
#
#                  공장주소_지번        공장관리번호
# 0   서울특별시 종로구 창성동 87-1번지  1.110000e+14
# 1  서울특별시 종로구 통의동 35-69번지  1.110000e+14
# 2  서울특별시 종로구 통의동 35-6번지   1.110000e+14
# 3  서울특별시 종로구 적선동 107-1번지  1.110000e+14
# 4      서울특별시 종로구 적선동 2번지  1.110000e+14
#
# [5 rows x 35 columns]

# %%
seoul.columns
# Out:
# Index(['시도명', '시군구명', '관리기관', '회사명', '공장구분', '단지명', '설립구분', '입주형태', '보유구분',
#        '등록구분', '전화번호', '남자종업원', '여자종업원', '외국인남자종업원', '외국인여자종업원', '종업원합계',
#        '생산품', '원자재', '공장규모', '용도지역', '지목', '용지면적', '제조시설면적', '부대시설면적', '건축면적',
#        '지식산업센터명', '대표업종', '업종명', '업종코드', '차수', '법인주소', '필지수', '공장주소',
#        '공장주소_지번', '공장관리번호'],
#       dtype='object')

# %% [markdown]
# ### 삭제할 칼럼
# 시도명, 시군구명, 관리기관, 회사명, 단지명, 전화번호, 법인주소, 필지수, 공장주소, 공장관리번호, 시
#
# ### 보류 칼럼 (일단 삭제)
# 생산품, 원자재, 업종명, 대표업종, 차수, 필지수
#
# ### 전처리 진행
# 용도지역, 업종코드 값 000 제거, 공장주소 지번 -> 동으로 쪼개기

# %%
seoul = seoul.drop(columns=['시도명', '시군구명', '관리기관', '회사명', '단지명', '전화번호', '법인주소', '필지수', '공장주소', '공장관리번호']) #1차
seoul = seoul.drop(columns=['생산품', '원자재', '업종명', '업종코드', '차수']) #2차

# %% [markdown]
# ### 공장주소_지번을 시, 구, 동으로 구분하기

# %%
address = seoul['공장주소_지번'].str.split(n=2, expand=True)
address[2] = address[2].str.split().str[0] #남은 부분에서 첫번째만 분리

print(address)

address.columns = ['시', '구', '동']
seoul = pd.concat([seoul, address[['시', '구', '동']]], axis=1)
seoul = seoul.drop(columns=['공장주소_지번', '시', '동'])
# Out:
#            0    1    2
# 0      서울특별시  종로구  창성동
# 1      서울특별시  종로구  통의동
# 2      서울특별시  종로구  통의동
# 3      서울특별시  종로구  적선동
# 4      서울특별시  종로구  적선동
# ...      ...  ...  ...
# 11628  서울특별시  강동구  천호동
# 11629  서울특별시  강동구  천호동
# 11630  서울특별시  강동구  천호동
# 11631  서울특별시  강동구  천호동
# 11632  서울특별시  강동구  천호동
#
# [11633 rows x 3 columns]

# %%
seoul.columns
# Out:
# Index(['공장구분', '설립구분', '입주형태', '보유구분', '등록구분', '남자종업원', '여자종업원', '외국인남자종업원',
#        '외국인여자종업원', '종업원합계', '공장규모', '용도지역', '지목', '용지면적', '제조시설면적', '부대시설면적',
#        '건축면적', '지식산업센터명', '대표업종', '구'],
#       dtype='object')

# %%
value_counts_df = seoul['지식산업센터명'].value_counts().reset_index()
value_counts_df.columns = ['지식산업센터명', '빈도수']

# Display the DataFrame
print(value_counts_df.to_string(index=False))
# Out:
#                       지식산업센터명  빈도수
#                               7225
#                      SK트윈테크타워   98
#                     대륭테크노타운8차   93
#                    대륭테크노타운12차   92
#                  벽산/경인디지털밸리2차   86
#                      우림라이온스밸리   76
#                     대륭테크노타운3차   65
#                      현대지식산업센터   60
#                     벽산디지털밸리5차   55
#                        한신IT타워   54
#                       한라시그마밸리   53
#                         센터플러스   51
#                    대륭테크노타운 5차   51
#                       디지털엠파이어   50
#                            SK   50
#                      갑을그레이트밸리   50
#                    대륭테크노타운 6차   50
#                       호서대벤처타워   48
#                    우림라이온스밸리2차   47
#                   에이스하이엔드타워9차   46
#                     에이스하이엔드타워   46
#                 에이스하이엔드타워 클래식   46
#                     에스티엑스브이타워   45
#                  에이스하이엔드8차(주)   45
#                     벽산디지털밸리6차   43
#                   에이스테크노타워 1차   43
#                  에이스하이엔드타워10차   42
#                     대륭테크노타운1차   40
#                     에이스하이테크시티   40
#               남성프라자(에이스테크노9차)   40
#                     대륭테크노타운2차   39
#                          스타밸리   37
#                    대륭테크노타운19차   37
#                    월드메르디앙벤처센터   36
#                        롯데IT캐슬   36
#                    대륭테크노타운18차   36
#                       가든파이브웍스   35
#                        이-스페이스   34
#                        SJ테크노빌   34
#                          뉴티캐슬   33
#                     동대문패션비즈센터   33
#                      강서한강자이타워   33
#                      아시아미디어타워   32
#                      STX W-타워   32
#                         리더스타워   32
#                     대륭포스트타워2차   31
#                   코오롱디지털타워빌란트   31
#                     이앤씨드림타워2차   31
#                     대륭포스트타워6차   31
#                        새한벤처월드   31
#                  월드메르디앙벤처센터2차   30
#                     대성 디큐브폴리스   30
#                       SK V1센터   30
#                        더루벤스밸리   30
#                   에이스테크노타워 2차   30
#                         아이티캐슬   29
#                    대륭테크노타운17차   29
#                      코오롱테크노밸리   29
#                    대륭테크노타운20차   29
#                     코오롱디지털에스턴   29
#                   코오롱싸이언스밸리2차   29
#                     이앤씨드림타워8차   29
#                       우림이비즈센터   28
#                     대륭포스트타워1차   28
#                     대륭포스트타워5차   28
#                       가양테크노타운   27
#                    한화비즈메트로 1차   27
#                     벽산디지털밸리1차   26
#                  우림블루나인비즈니스센터   26
#                   에이스테크노타워10차   26
#                 에이스트윈타워(6,7차)   26
#                   에이스하이엔드타워6차   25
#                  에이스하이엔드7차(주)   24
#                   에이스하이엔드타워3차   24
#                       우영테크노센타   24
#                     이앤씨드림타워7차   24
#           BYC HIGHCITY 아파트형공장   24
#                   에이스테크노타워 3차   24
#                    우림e-BIZ센타Ⅱ   24
#                 코오롱디지털타워빌란트2차   23
#                     대륭포스트타워7차   23
#                      백상스타타워2차   23
#                      IT프리미어타워   22
#                      마리오디지털타워   22
#                     우림이비즈센터2차   22
#                      에이스테크노타워   21
#                      신트리테크노타운   21
#                       하계테크노타운   21
#                        센츄리프라자   20
#                      문정역 테라타워   20
#                   에이스테크노타워 8차   20
#                        삼성IT밸리   19
#                    대륭테크노타운 7차   19
#                     이앤씨드림타워6차   19
#                        파트너스타워   19
#                         가산W센터   18
#                    서울제일인쇄협동조합   18
#                      백상스타타워1차   17
#                       에이스가산타워   16
#                       KCC웰츠밸리   16
#                   에이스테크노타워 5차   16
#                     벽산디지털밸리3차   16
#                     이앤씨드림타워5차   16
#                    대륭테크노타운13차   16
#                       신내테크노타운   16
#                     벽산디지털밸리7차   16
#                      JNK디지털타워   15
#                        IT미래타워   15
#                     이앤씨드림타워3차   15
#                        한국전자협동   14
#                  지플러스코오롱디지털타워   14
#                      한신IT타워2차   14
#                     에이치비지니스파크   14
#                         고려테크온   14
#                      KnK디지털타워   13
#                       윈스타워관리단   13
#                 서울숲코오롱디지털타워3차   13
#                       에이스한솔타워   13
#                    동일테크노타운 2차   13
#                       대군인더스타운   13
#                 성수동 아이에스 비즈타워   13
#                    대륭테크노타운21차   12
#                      송파 테라타워2   12
#                       이앤씨드림타워   12
#                     삼환디지털벤처타워   12
#                   에이스하이엔드타워5차   12
#                        더스카이밸리   12
#                     대륭포스트타워3차   12
#                   코오롱싸이언스밸리1차   11
#                        한신아크밸리   11
#                      문정 대명벨리온   11
#                문정 현대지식산업센터Ⅰ-2   11
#                          엘리시아   10
#                      한섬아파트형공장   10
#                   에이스하이앤드타워2차   10
#                       영동테크노타워   10
#                    동일테크노타운 1차   10
#               선유도역1차 아이에스비즈타워   10
#                  선유도 코오롱디지털타워   10
#                       신한이노플렉스   10
#                            천강   10
#                        지-하이시티   10
#                       동아프라임밸리    9
#                        강서IT밸리    9
#                            풍림    9
#                          휴먼테코    9
#                         풍림테크원    8
#                       우리벤처타운Ⅱ    8
#              남영아파트형공장(변경전:아주)    8
#                            대동    8
#                문정 현대지식산업센터Ⅰ-1    8
#                    가양비즈메트로 이차    8
#                   더스카이밸리 가산2차    8
#                            삼풍    8
# 성수동 우림e-BIZ Center(변경전:이비즈센타)    8
#                    서울숲 코오롱 1차    8
#                        승일벤처타워    8
#                     대륭포스트타워8차    7
#                      진도아파트형공장    7
#                   서울숲 한라시그마밸리    7
#               월계공장집단화 사업 협동조합    7
#                   문래동에이스테크노타워    7
#                      (주)진도에프앤    7
#                         지영플라자    7
#                       에이스비즈포레    7
#                    서울숲 한라에코밸리    7
#                구로대명밸리온 지식산업센터    7
#                    가양비즈메트로 일차    7
#            문정 에스케이브이원 지엘메트로시티    6
#                  SK V1 center    6
#                    에이스하이테크시티2    6
#                        두앤캔하우스    6
#                      빅토리테크노타워    6
#                       동일테크노타운    6
#                        우리벤처타운    6
#                     JEI PLATZ    5
#                         (주)삼우    5
#                    월드메르디앙비즈센터    5
#                 선유도 우림라이온스밸리B    5
#                     삼성IT해링턴타워    5
#                 강서 한화비즈메트로 이차    5
#                          삼성문화    5
#                 강서 한화비즈메트로 일차    5
#                      문래 SK V1    4
#                      파트너스타워2차    4
#                        메가벤처타워    4
#                  서울숲한라시그마밸리II    4
#                 선유도 우림라이온스밸리A    4
#                      세종앤까뮤스퀘어    4
#                        강북전자공단    4
#                       이노플렉스1차    4
#                 서울숲코오롱디지털타워2차    4
#                      강남 에이스타워    4
#                    드림마크원데이터센타    4
#                        IT캐슬2차    4
#                    지산 IT 벤쳐센터    4
#                      가산비즈니스센터    4
#                    이글타운아파트형공장    3
#                       NHN KCP    3
#              DMC도시형공장(첨단산업센터)    3
#                       중계 제1공단    3
#                    경인전자벤처센터 2    3
#                       서울숲IT밸리    3
#                       강북유니온빌딩    3
#                     하우스디 세종타워    3
#                        하우스디비즈    2
#                     양평동 이노플렉스    2
#                     마리오-2패션타워    2
#                  서울숲 드림타워(삼공)    2
#                    금강펜테리움IT타워    2
#                     더 리브 골드타워    2
#                        케이투코라아    2
#                        케이디유타워    1
#                      성수 에이팩센터    1
#                      송파유탑테크밸리    1
#                          아남빌딩    1
#               선유도역2차 아이에스비즈타워    1
#                      솔버스 비즈센터    1
#                    에이스하이테크시티3    1
#                     서울숲  ITCT    1
#                    월드메리디앙벤처센터    1
#               가산동 아파트형 공장(가제)    1
#                       서울숲IT캐슬    1
#                      에스비즈니스센터    1
#                     ENH아파트형공장    1
#                         아벨테크노    1
#                         엠스테이트    1

# %%
df_count = seoul['용도지역'].value_counts().reset_index()
df_count.columns = ['용도지역', '빈도수']

print(df_count.to_string(index=False))
# Out:
#                           용도지역  빈도수
#               도시지역/공업지역/준공업지역/ 6104
#           도시지역/주거지역/제2종일반주거지역/ 1143
#              도시지역/상업지역/일반상업지역/  682
#                도시지역/주거지역/주거지역/  648
#           도시지역/주거지역/제3종일반주거지역/  628
#              도시지역/상업지역/근린상업지역/  511
#           도시지역/공업지역/준공업지역/고도지구  207
#       도시지역/주거지역/제2종일반주거지역/기타지역  201
#           도시지역/공업지역/준공업지역/기타지역  200
#               도시지역/주거지역/준주거지역/  195
#       도시지역/주거지역/제3종일반주거지역/미관지구  114
#                도시지역/공업지역/공업지역/   97
#           도시지역/주거지역/제1종일반주거지역/   84
#       도시지역/주거지역/제2종일반주거지역/미관지구   67
#          도시지역/상업지역/일반상업지역/방화지구   63
#       도시지역/주거지역/제2종일반주거지역/고도지구   59
#       도시지역/주거지역/제3종일반주거지역/기타지역   56
#              도시지역/상업지역/중심상업지역/   50
#          도시지역/상업지역/일반상업지역/기타지역   45
#              도시지역/상업지역/유통상업지역/   36
#          도시지역/상업지역/일반상업지역/미관지구   32
#              도시지역/녹지지역/자연녹지지역/   26
# 도시지역/주거지역/제2종일반주거지역/지구단위1종수립지구   25
#       도시지역/주거지역/제3종일반주거지역/고도지구   23
#        도시지역/상업지역/일반상업지역/개발진흥지구   22
#              도시지역/공업지역/일반공업지역/   20
#                                  19
#    도시지역/상업지역/일반상업지역/지구단위1종수립지구   17
# 도시지역/주거지역/제3종일반주거지역/지구단위1종수립지구   14
#         도시지역/공업지역/준공업지역/개발진흥지구   14
#           도시지역/주거지역/제2종전용주거지역/   14
#           도시지역/주거지역/준주거지역/미관지구   11
#          도시지역/상업지역/근린상업지역/기타지역   11
#              도시지역/공업지역/전용공업지역/   10
#     도시지역/주거지역/제2종일반주거지역/시설보호지구   10
#       도시지역/주거지역/제2종일반주거지역/경관지구   10
#     도시지역/공업지역/준공업지역/지구단위1종수립지구   10
#       도시지역/주거지역/제1종일반주거지역/기타지역    9
#     도시지역/주거지역/준주거지역/지구단위1종수립지구    9
#         도시지역/공업지역/준공업지역/시설보호지구    8
#       도시지역/주거지역/제1종일반주거지역/경관지구    8
#           도시지역/주거지역/준주거지역/고도지구    7
#           도시지역/주거지역/준주거지역/기타지역    7
#           도시지역/공업지역/준공업지역/미관지구    7
#    도시지역/상업지역/일반상업지역/지구단위2종수립지구    6
#       도시지역/주거지역/제2종일반주거지역/개발지구    6
#            관리지역/계획관리지역/계획관리지역/    6
#       도시지역/주거지역/제1종일반주거지역/고도지구    5
#          도시지역/녹지지역/자연녹지지역/기타지역    5
# 도시지역/주거지역/제2종일반주거지역/지구단위2종수립지구    5
#          도시지역/상업지역/일반상업지역/고도지구    5
#       도시지역/주거지역/제1종일반주거지역/미관지구    4
#          도시지역/상업지역/근린상업지역/고도지구    4
#    도시지역/녹지지역/자연녹지지역/지구단위1종수립지구    3
#              도시지역/녹지지역/생산녹지지역/    3
#     도시지역/주거지역/제2종일반주거지역/개발진흥지구    3
# 도시지역/주거지역/제1종일반주거지역/지구단위1종수립지구    3
#          도시지역/상업지역/일반상업지역/경관지구    3
#           도시지역/주거지역/제1종전용주거지역/    2
#     도시지역/주거지역/제3종일반주거지역/시설보호지구    2
#       도시지역/주거지역/제2종일반주거지역/취락지구    2
#           도시지역/공업지역/준공업지역/개발지구    2
#          도시지역/상업지역/근린상업지역/미관지구    2
#          도시지역/녹지지역/자연녹지지역/고도지구    2
#          도시지역/공업지역/일반공업지역/기타지역    2
#       도시지역/주거지역/제2종일반주거지역/방화지구    2
#       도시지역/주거지역/제3종일반주거지역/개발지구    2
#     도시지역/공업지역/준공업지역/지구단위2종수립지구    2
#   도시지역/주거지역/제2종일반주거지역/특정용도제한지구    2
#           도시지역  도시지역  준공업지역       1
#        도시지역/상업지역/일반상업지역/시설보호지구    1
#          도시지역/공업지역/전용공업지역/기타지역    1
#     도시지역/주거지역/제1종일반주거지역/시설보호지구    1
#    도시지역/상업지역/유통상업지역/지구단위1종수립지구    1
#          도시지역/상업지역/유통상업지역/기타지역    1
#           도시지역/주거지역/준주거지역/개발지구    1
#         도시지역/주거지역/준주거지역/시설보호지구    1
#           도시지역/공업지역/준공업지역/방화지구    1
#    도시지역/상업지역/근린상업지역/지구단위1종수립지구    1
#     도시지역/주거지역/제3종일반주거지역/개발진흥지구    1
#          도시지역/상업지역/근린상업지역/경관지구    1
#              도시지역/녹지지역/보전녹지지역/    1
#       도시지역/주거지역/제2종전용주거지역/기타지역    1
#        관리지역/계획관리지역/계획관리지역/미관지구    1
#       도시지역/주거지역/제3종일반주거지역/경관지구    1
# 도시지역/주거지역/제3종일반주거지역/지구단위2종수립지구    1

# %%
# def simplify_land_use(land_use):
#     parts = land_use.split('/')
#     if len(parts) >= 2:
#         return '/'.join(parts[:2])  # 주요 카테고리 2개만 남김
#     else:
#         return land_use

# # 용도지역 일반화 적용
# df_count['용도지역_일반화'] = df_count['용도지역'].apply(simplify_land_use)

# # 결과 출력
# df_count = df_count['용도지역_일반화'].value_counts().reset_index()
# df_count.columns = ['용도지역_일반화', '빈도수']

# print(df_count.to_string(index=False))

# %%
# seoul['용도지역'] = seoul['용도지역'].apply(simplify_land_use)

# %%
seoul['용도지역'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        도시지역/주거지역/제2종일반주거지역/고도지구
# 1                 도시지역/주거지역/주거지역/
# 2                 도시지역/주거지역/주거지역/
# 3        도시지역/주거지역/제2종일반주거지역/미관지구
# 4               도시지역/상업지역/일반상업지역/
#                    ...
# 11628    도시지역/주거지역/제2종일반주거지역/기타지역
# 11629             도시지역/주거지역/주거지역/
# 11630    도시지역/주거지역/제2종일반주거지역/기타지역
# 11631    도시지역/주거지역/제3종일반주거지역/미관지구
# 11632    도시지역/주거지역/제3종일반주거지역/미관지구
# Name: 용도지역, Length: 11633, dtype: object>

# %%
seoul
# Out:
#       공장구분 설립구분   입주형태 보유구분  등록구분  남자종업원  여자종업원  외국인남자종업원  외국인여자종업원  종업원합계  \
# 0       개별   일반   해당없음   임대  신규등록      0      0         0         0      0
# 1       개별   일반   해당없음   임대  등록변경      5      2         0         0      7
# 2       개별   일반   해당없음   자가  등록변경     12     12         0         0     24
# 3       개별   일반   해당없음   임대  신규등록      0      0         0         0      0
# 4       개별   일반   해당없음   임대  등록변경      7      2         0         0      9
# ...    ...  ...    ...  ...   ...    ...    ...       ...       ...    ...
# 11628   개별   일반  일반건축물   임대  등록변경      1      4         0         0      5
# 11629   개별   일반   해당없음   자가  등록변경      0      0         0         0      0
# 11630   개별   일반  일반건축물   임대  등록변경      7      0         0         0      7
# 11631   개별   일반  일반건축물   임대  신규등록      2      3         0         0      5
# 11632   개별   일반  일반건축물   임대  신규등록      2      3         0         0      5
#
#       공장규모                      용도지역 지목    용지면적  제조시설면적  부대시설면적    건축면적  \
# 0      소기업  도시지역/주거지역/제2종일반주거지역/고도지구  대  238.00   57.12   69.44  126.56
# 1      소기업           도시지역/주거지역/주거지역/  대  157.55   79.11   78.44  157.55
# 2      소기업           도시지역/주거지역/주거지역/  대  160.30   92.40   67.90  160.30
# 3      소기업  도시지역/주거지역/제2종일반주거지역/미관지구  대  280.00   35.00   88.50  123.50
# 4      소기업         도시지역/상업지역/일반상업지역/  대  122.30  159.93   18.00  177.93
# ...    ...                       ... ..     ...     ...     ...     ...
# 11628  소기업  도시지역/주거지역/제2종일반주거지역/기타지역  대  104.31  104.31    0.00  104.31
# 11629  소기업           도시지역/주거지역/주거지역/  대  164.61  110.74   53.87  164.61
# 11630  소기업  도시지역/주거지역/제2종일반주거지역/기타지역  대  125.28  114.28   11.00  125.28
# 11631  소기업  도시지역/주거지역/제3종일반주거지역/미관지구  대  104.15  104.15    0.00  104.15
# 11632  소기업  도시지역/주거지역/제3종일반주거지역/미관지구  대  104.15  104.15    0.00  104.15
#
#       지식산업센터명   대표업종    구
# 0              18111  종로구
# 1              33932  종로구
# 2              58113  종로구
# 3              18111  종로구
# 4              18119  종로구
# ...       ...    ...  ...
# 11628          14199  강동구
# 11629          33120  강동구
# 11630          15121  강동구
# 11631          13222  강동구
# 11632          13222  강동구
#
# [11633 rows x 20 columns]

# %% [markdown]
# ### Preprocessing

# %%
seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11633 entries, 0 to 11632
# Data columns (total 20 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   공장구분      11633 non-null  object
#  1   설립구분      11633 non-null  object
#  2   입주형태      11633 non-null  object
#  3   보유구분      11633 non-null  object
#  4   등록구분      11633 non-null  object
#  5   남자종업원     11633 non-null  int64
#  6   여자종업원     11633 non-null  int64
#  7   외국인남자종업원  11633 non-null  int64
#  8   외국인여자종업원  11633 non-null  int64
#  9   종업원합계     11633 non-null  int64
#  10  공장규모      11633 non-null  object
#  11  용도지역      11633 non-null  object
#  12  지목        11633 non-null  object
#  13  용지면적      11633 non-null  float64
#  14  제조시설면적    11633 non-null  float64
#  15  부대시설면적    11633 non-null  float64
#  16  건축면적      11633 non-null  float64
#  17  지식산업센터명   11633 non-null  object
#  18  대표업종      11633 non-null  int64
#  19  구         11633 non-null  object
# dtypes: float64(4), int64(6), object(10)
# memory usage: 1.8+ MB

# %%
object_columns = ['공장구분', '설립구분', '입주형태', '보유구분', '등록구분', '공장규모', '용도지역', '지목', '지식산업센터명', '대표업종', '구']
int_columns = ['남자종업원', '여자종업원', '외국인남자종업원', '외국인여자종업원', '종업원합계','용지면적', '제조시설면적', '부대시설면적', '건축면적']

# %%
seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11633 entries, 0 to 11632
# Data columns (total 20 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   공장구분      11633 non-null  object
#  1   설립구분      11633 non-null  object
#  2   입주형태      11633 non-null  object
#  3   보유구분      11633 non-null  object
#  4   등록구분      11633 non-null  object
#  5   남자종업원     11633 non-null  int64
#  6   여자종업원     11633 non-null  int64
#  7   외국인남자종업원  11633 non-null  int64
#  8   외국인여자종업원  11633 non-null  int64
#  9   종업원합계     11633 non-null  int64
#  10  공장규모      11633 non-null  object
#  11  용도지역      11633 non-null  object
#  12  지목        11633 non-null  object
#  13  용지면적      11633 non-null  float64
#  14  제조시설면적    11633 non-null  float64
#  15  부대시설면적    11633 non-null  float64
#  16  건축면적      11633 non-null  float64
#  17  지식산업센터명   11633 non-null  object
#  18  대표업종      11633 non-null  int64
#  19  구         11633 non-null  object
# dtypes: float64(4), int64(6), object(10)
# memory usage: 1.8+ MB

# %%
# object 타입 변환
for column in object_columns:
    seoul[column] = seoul[column].astype('object')

for column in int_columns:
    seoul[column] = seoul[column].astype('int')

# %% [markdown]
# ## 시각화 함수

# %%
def plot_value_counts(df = seoul, columns=None, max_categories=20):
    '''특정 컬럼들의 value_counts를 시각화하는 함수'''
    if columns is None:
        columns = df.columns

    for col in columns:
        if df[col].dtype == 'object':
            plt.figure(figsize=(10, 6))
            count_series = df[col].value_counts().nlargest(max_categories)
            sns.barplot(x=count_series.index, y=count_series.values, palette='viridis')
            plt.title(f'{col} - value_counts')
            plt.xlabel(col)
            plt.ylabel('Count')
            plt.xticks(rotation=45)

            # 막대 끝에 라벨 추가
            for index, value in enumerate(count_series.values):
                plt.text(index, value, f'{value}', ha='center', va='bottom')

            plt.show()

# %%
plot_value_counts(seoul)

# %%
seoul['공장구분'].value_counts()
# Out:
# 개별    8107
# 계획    3526
# Name: 공장구분, dtype: int64

# %%
seoul['설립구분'].value_counts()
# Out:
# 일반        8055
# 국가산업단지    3028
# 지식산업센터     427
# 일반산업단지      71
# 창업          52
# Name: 설립구분, dtype: int64

# %%
seoul['입주형태'].value_counts()
# Out:
# 해당없음     3119
# 일반건축물    2273
# 분양       1515
# 공장임대     1495
# 양수도      1325
#          1231
# 임대사업자     346
# 기타        232
# 경매         80
# 일반토지       17
# Name: 입주형태, dtype: int64

# %%
seoul['입주형태'] = seoul['입주형태'].str.strip() # 공백제거
seoul['입주형태'].replace('', '해당없음', inplace=True)
seoul['입주형태'].fillna('해당없음', inplace=True)

# %%
seoul['입주형태'].value_counts()
# Out:
# 해당없음     4350
# 일반건축물    2273
# 분양       1515
# 공장임대     1495
# 양수도      1325
# 임대사업자     346
# 기타        232
# 경매         80
# 일반토지       17
# Name: 입주형태, dtype: int64

# %%
seoul['보유구분'].value_counts()
# Out:
# 임대    6347
# 자가    5286
# Name: 보유구분, dtype: int64

# %%
seoul['등록구분'].value_counts()
# Out:
# 신규등록    5232
# 등록변경    3477
# 완료신고    2874
# 부분등록      50
# Name: 등록구분, dtype: int64

# %%
seoul['공장규모'].value_counts()
# Out:
# 소기업    11237
# 중기업      364
# 대기업       32
# Name: 공장규모, dtype: int64

# %%
seoul['용도지역'].value_counts()
# Out:
# 도시지역/공업지역/준공업지역/                  6104
# 도시지역/주거지역/제2종일반주거지역/              1143
# 도시지역/상업지역/일반상업지역/                  682
# 도시지역/주거지역/주거지역/                    648
# 도시지역/주거지역/제3종일반주거지역/               628
#                                   ...
# 도시지역/녹지지역/보전녹지지역/                    1
# 도시지역/주거지역/제2종전용주거지역/기타지역             1
# 관리지역/계획관리지역/계획관리지역/미관지구              1
# 도시지역/주거지역/제3종일반주거지역/경관지구             1
# 도시지역/주거지역/제3종일반주거지역/지구단위2종수립지구       1
# Name: 용도지역, Length: 86, dtype: int64

# %%
seoul['용도지역'] = seoul['용도지역'].str.strip() # 공백제거
seoul['용도지역'].replace('', '해당없음', inplace=True)
seoul['입주형태'].fillna('해당없음', inplace=True)

# %%
seoul['용도지역'].value_counts()
# Out:
# 도시지역/공업지역/준공업지역/                  6104
# 도시지역/주거지역/제2종일반주거지역/              1143
# 도시지역/상업지역/일반상업지역/                  682
# 도시지역/주거지역/주거지역/                    648
# 도시지역/주거지역/제3종일반주거지역/               628
#                                   ...
# 도시지역/녹지지역/보전녹지지역/                    1
# 도시지역/주거지역/제2종전용주거지역/기타지역             1
# 관리지역/계획관리지역/계획관리지역/미관지구              1
# 도시지역/주거지역/제3종일반주거지역/경관지구             1
# 도시지역/주거지역/제3종일반주거지역/지구단위2종수립지구       1
# Name: 용도지역, Length: 86, dtype: int64

# %%
seoul['지목'].value_counts()
# Out:
# 대          6025
# 공장용지       5500
#              33
# 답            24
# 학교용지         21
# 잡종지           8
# 대, 공장용지       5
# 도로            4
# 전             3
# 임야            3
# 창고용지          2
# 제방            1
# 대, 학교용지       1
# 하천            1
# 철도용지          1
# 사적지           1
# Name: 지목, dtype: int64

# %%
seoul['지목'] = seoul['지목'].str.strip() # 공백제거
seoul['지목'].replace('', '해당없음', inplace=True)
seoul['지목'].fillna('해당없음', inplace=True)

# %%
seoul['지목'].value_counts()
# Out:
# 대          6025
# 공장용지       5500
# 해당없음         33
# 답            24
# 학교용지         21
# 잡종지           8
# 대, 공장용지       5
# 도로            4
# 전             3
# 임야            3
# 창고용지          2
# 제방            1
# 대, 학교용지       1
# 하천            1
# 철도용지          1
# 사적지           1
# Name: 지목, dtype: int64

# %%
seoul['지식산업센터명'].value_counts()
# Out:
#                 7225
# SK트윈테크타워          98
# 대륭테크노타운8차         93
# 대륭테크노타운12차        92
# 벽산/경인디지털밸리2차      86
#                 ...
# 서울숲IT캐슬            1
# 에스비즈니스센터           1
# ENH아파트형공장          1
# 아벨테크노              1
# 엠스테이트              1
# Name: 지식산업센터명, Length: 227, dtype: int64

# %%
seoul['지식산업센터명'] = seoul['지식산업센터명'].str.strip() # 공백제거
seoul['지식산업센터명'].replace('', '해당없음', inplace=True)
seoul['지식산업센터명'].fillna('해당없음', inplace=True)

# %%
seoul['지식산업센터명'].value_counts()
# Out:
# 해당없음            7225
# SK트윈테크타워          98
# 대륭테크노타운8차         93
# 대륭테크노타운12차        92
# 벽산/경인디지털밸리2차      86
#                 ...
# 서울숲IT캐슬            1
# 에스비즈니스센터           1
# ENH아파트형공장          1
# 아벨테크노              1
# 엠스테이트              1
# Name: 지식산업센터명, Length: 227, dtype: int64

# %%
seoul['구'].value_counts()
# Out:
# 금천구     3455
# 성동구     1357
# 구로구     1215
# 중구      1190
# 영등포구     845
# 강서구      642
# 송파구      428
# 중랑구      341
# 동대문구     265
# 강남구      228
# 서초구      208
# 광진구      174
# 종로구      166
# 도봉구      155
# 강동구      129
# 양천구      108
# 노원구      105
# 성북구      103
# 마포구      102
# 은평구       94
# 강북구       89
# 용산구       77
# 관악구       65
# 서대문구      52
# 동작구       40
# Name: 구, dtype: int64

# %%
seoul['남자종업원'].value_counts()
# Out:
# 2      1483
# 3      1459
# 4      1319
# 5      1083
# 1      1009
#        ...
# 174       1
# 98        1
# 101       1
# 108       1
# 82        1
# Name: 남자종업원, Length: 156, dtype: int64

# %%
seoul['여자종업원'].value_counts()
# Out:
# 1      3052
# 0      2476
# 2      1911
# 3      1088
# 4       688
#        ...
# 151       1
# 200       1
# 130       1
# 94        1
# 89        1
# Name: 여자종업원, Length: 105, dtype: int64

# %%
seoul['외국인남자종업원'].value_counts()
# Out:
# 0     11356
# 1       127
# 2        49
# 3        26
# 4        19
# 5        14
# 6         7
# 8         6
# 10        6
# 7         4
# 11        3
# 9         3
# 21        3
# 13        2
# 12        2
# 71        1
# 14        1
# 17        1
# 15        1
# 23        1
# 16        1
# Name: 외국인남자종업원, dtype: int64

# %%
seoul['외국인여자종업원'].value_counts()
# Out:
# 0      11531
# 1         54
# 2         23
# 3          6
# 4          5
# 5          3
# 6          2
# 8          2
# 10         2
# 13         1
# 129        1
# 64         1
# 17         1
# 19         1
# Name: 외국인여자종업원, dtype: int64

# %%
seoul['용지면적'].value_counts()
# Out:
# 0       3169
# 33       111
# 34       107
# 66        88
# 35        82
#         ...
# 575        1
# 588        1
# 1865       1
# 804        1
# 382        1
# Name: 용지면적, Length: 1194, dtype: int64

# %%
seoul['제조시설면적'].value_counts()
# Out:
# 132     151
# 100     145
# 33      138
# 50      136
# 60      126
#        ...
# 1055      1
# 1562      1
# 1657      1
# 6768      1
# 947       1
# Name: 제조시설면적, Length: 1122, dtype: int64

# %%
seoul['부대시설면적'].value_counts()
# Out:
# 0       2926
# 33       127
# 20       126
# 30       112
# 10       112
#         ...
# 7280       1
# 1926       1
# 462        1
# 1223       1
# 4032       1
# Name: 부대시설면적, Length: 932, dtype: int64

# %%
seoul['건축면적'].value_counts()
# Out:
# 132     110
# 66       87
# 165      85
# 220      84
# 198      80
#        ...
# 1252      1
# 717       1
# 1312      1
# 1067      1
# 4230      1
# Name: 건축면적, Length: 1484, dtype: int64

# %%
seoul.isnull().sum()
# Out:
# 공장구분        0
# 설립구분        0
# 입주형태        0
# 보유구분        0
# 등록구분        0
# 남자종업원       0
# 여자종업원       0
# 외국인남자종업원    0
# 외국인여자종업원    0
# 종업원합계       0
# 공장규모        0
# 용도지역        0
# 지목          0
# 용지면적        0
# 제조시설면적      0
# 부대시설면적      0
# 건축면적        0
# 지식산업센터명     0
# 대표업종        0
# 구           0
# dtype: int64

# %%
seoul['구'].value_counts()
# Out:
# 금천구     3455
# 성동구     1357
# 구로구     1215
# 중구      1190
# 영등포구     845
# 강서구      642
# 송파구      428
# 중랑구      341
# 동대문구     265
# 강남구      228
# 서초구      208
# 광진구      174
# 종로구      166
# 도봉구      155
# 강동구      129
# 양천구      108
# 노원구      105
# 성북구      103
# 마포구      102
# 은평구       94
# 강북구       89
# 용산구       77
# 관악구       65
# 서대문구      52
# 동작구       40
# Name: 구, dtype: int64

# %%
# '구' 칼럼 라벨 인코딩
label_encoder_gu = LabelEncoder()
seoul['구'] = label_encoder_gu.fit_transform(seoul['구'])

X = seoul.drop(columns=['구'])
y = seoul['구']

# %%
print(X.shape, y.shape)
# Out:
# (11633, 19) (11633,)

# %%
y.value_counts()
# Out:
# 7     3455
# 15    1357
# 6     1215
# 23    1190
# 19     845
# 3      642
# 17     428
# 24     341
# 10     265
# 0      228
# 14     208
# 5      174
# 22     166
# 9      155
# 1      129
# 18     108
# 8      105
# 16     103
# 12     102
# 21      94
# 2       89
# 20      77
# 4       65
# 13      52
# 11      40
# Name: 구, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state=42)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.2, random_state = 42)

print(X_train.shape, X_val.shape, X_test.shape, y_train.shape, y_val.shape, y_test.shape)
# Out:
# (7910, 19) (1978, 19) (1745, 19) (7910,) (1978,) (1745,)

# %%
from sklearn.preprocessing import LabelEncoder
from category_encoders import TargetEncoder

# 범주형 피처들을 찾아 리스트에 저장
categorical_features = list(X_train.dtypes[X_train.dtypes == "object"].index)

display(categorical_features)
# TargetEncoder 초기화
te = TargetEncoder()

# Target encoding 적용
X_train[categorical_features] = te.fit_transform(X_train[categorical_features], y_train)
X_val[categorical_features] = te.transform(X_val[categorical_features])
X_test[categorical_features] = te.transform(X_test[categorical_features])

# 결과 확인
display(X_train)
display(X_test)
# Out:
# ['공장구분',
#  '설립구분',
#  '입주형태',
#  '보유구분',
#  '등록구분',
#  '공장규모',
#  '용도지역',
#  '지목',
#  '지식산업센터명',
#  '대표업종']
#            공장구분       설립구분       입주형태       보유구분       등록구분  남자종업원  여자종업원  \
# 2548  13.657631  13.648856  13.211725   9.631666  13.875667     10      1
# 5896   6.723166   6.764961   6.956092   9.631666   7.249112     32      6
# 2660  13.657631  13.648856  13.211725  13.153577  11.511102      5     12
# 8386   6.723166   6.651724   6.956092   9.631666   7.249112      2      9
# 3536  13.657631  13.648856  14.906292  13.153577  13.875667      4      0
# ...         ...        ...        ...        ...        ...    ...    ...
# 4166  13.657631  13.648856  14.906292  13.153577  11.511102      1      2
# 9825  13.657631  13.648856  13.211725  13.153577   7.249112     24      1
# 4383  13.657631  13.648856  13.211725   9.631666   7.249112     11      2
# 1315  13.657631  13.648856  14.906292  13.153577  13.875667      1      1
# 5416   6.723166   6.764961   9.012605  13.153577   7.249112      2      0
#
#       외국인남자종업원  외국인여자종업원  종업원합계       공장규모       용도지역         지목  용지면적  \
# 2548         2         0     13  11.609539   9.257934  12.949682   495
# 5896         1         0     39  11.609539   9.257934   9.997594   208
# 2660         0         0     17  11.609539  12.282759  12.949682   904
# 8386         0         0     11  11.609539   9.257934   9.997594    66
# 3536         0         0      4  11.609539  12.107910  12.949682     0
# ...        ...       ...    ...        ...        ...        ...   ...
# 4166         0         0      3  11.609539  11.808160  12.949682   170
# 9825         0         0     25  11.609539   9.257934   9.997594   601
# 4383         0         0     13  11.609539   9.257934  12.949682   359
# 1315         0         0      2  11.609539  20.089716   9.997594     0
# 5416         0         0      2  11.609539   9.257934   9.997594     0
#
#       제조시설면적  부대시설면적  건축면적    지식산업센터명       대표업종
# 2548     245      54   299  13.373306  10.464750
# 5896     816     636  1452   9.940242   9.144201
# 2660      72      26    98  13.373306  13.143564
# 8386     271     175   446   7.215419  10.115972
# 3536     131     160   292  13.373306   9.596854
# ...      ...     ...   ...        ...        ...
# 4166      22     148   170  13.373306  10.997769
# 9825     412     220   632  13.373306   9.545701
# 4383       0     110   110  13.373306  10.744173
# 1315      65       0    65  18.124058  12.978250
# 5416      54      35    90   8.909553   9.969697
#
# [7910 rows x 19 columns]
#             공장구분       설립구분       입주형태       보유구분       등록구분  남자종업원  여자종업원  \
# 3094   13.657631  13.648856  14.906292  13.153577  13.875667      1      0
# 11270  13.657631  13.648856   8.665081   9.631666  13.875667      2      2
# 9641   13.657631  13.648856  13.211725  13.153577  13.875667      3      7
# 9128   13.657631  13.648856  13.211725   9.631666  11.511102      1      0
# 3912   13.657631  13.648856   9.253937  13.153577  13.875667      0      3
# ...          ...        ...        ...        ...        ...    ...    ...
# 7110    6.723166   6.764961   9.253937  13.153577  11.511102     10      1
# 9934   13.657631  13.648856  13.211725   9.631666  13.875667      2      0
# 2993   13.657631  13.648856  14.906292  13.153577  11.511102      4      6
# 1851   13.657631  13.648856   9.253937  13.153577  11.511102      5      2
# 9053   13.657631  13.648856  13.211725   9.631666  13.875667     15      0
#
#        외국인남자종업원  외국인여자종업원  종업원합계       공장규모       용도지역         지목  용지면적  \
# 3094          0         0      1  11.609539  10.501199  12.949682     0
# 11270         0         0      4  11.609539  20.089716  12.949682   155
# 9641          0         0     10  11.609539  13.006928  12.949682   341
# 9128          0         0      1  11.609539   6.608733  12.949682   534
# 3912          0         0      3  11.609539  12.107910  12.949682   106
# ...         ...       ...    ...        ...        ...        ...   ...
# 7110          0         0     11  11.609539   9.257934   9.997594     0
# 9934          0         0      2  11.609539   9.257934   9.997594     0
# 2993          0         0     10  11.609539  10.501199  12.949682     0
# 1851          0         0      7  11.609539   9.257934  12.949682   147
# 9053          0         0     15  11.609539   9.257934  12.949682   694
#
#        제조시설면적  부대시설면적  건축면적    지식산업센터명       대표업종
# 3094       66      35   101  13.373306  12.715189
# 11270      60      95   155  13.476153  10.840609
# 9641      303      38   341  13.373306  12.772168
# 9128       15       0    15  13.373306   9.599757
# 3912       25      81   106  13.373306   9.969944
# ...       ...     ...   ...        ...        ...
# 7110       97       0    97  13.373306   9.386627
# 9934      123      17   140  17.747231  11.503299
# 2993      132       0   132  13.373306  13.143564
# 1851        6      64    70  13.373306  19.728610
# 9053      829       0   829  13.373306   9.545701
#
# [1745 rows x 19 columns]

# %%
print(X_train.info(), X.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7910 entries, 2548 to 5416
# Data columns (total 19 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   공장구분      7910 non-null   float64
#  1   설립구분      7910 non-null   float64
#  2   입주형태      7910 non-null   float64
#  3   보유구분      7910 non-null   float64
#  4   등록구분      7910 non-null   float64
#  5   남자종업원     7910 non-null   int32
#  6   여자종업원     7910 non-null   int32
#  7   외국인남자종업원  7910 non-null   int32
#  8   외국인여자종업원  7910 non-null   int32
#  9   종업원합계     7910 non-null   int32
#  10  공장규모      7910 non-null   float64
#  11  용도지역      7910 non-null   float64
#  12  지목        7910 non-null   float64
#  13  용지면적      7910 non-null   int32
#  14  제조시설면적    7910 non-null   int32
#  15  부대시설면적    7910 non-null   int32
#  16  건축면적      7910 non-null   int32
#  17  지식산업센터명   7910 non-null   float64
#  18  대표업종      7910 non-null   float64
# dtypes: float64(10), int32(9)
# memory usage: 957.9 KB
# None 공장구분        0
# 설립구분        0
# 입주형태        0
# 보유구분        0
# 등록구분        0
# 남자종업원       0
# 여자종업원       0
# 외국인남자종업원    0
# 외국인여자종업원    0
# 종업원합계       0
# 공장규모        0
# 용도지역        0
# 지목          0
# 용지면적        0
# 제조시설면적      0
# 부대시설면적      0
# 건축면적        0
# 지식산업센터명     0
# 대표업종        0
# dtype: int64

# %%
from tarfile import XGLTYPE
#학습을 위한 라이브러리 세팅
# from sklearn.linear_model import LogisticRegression
# from xgboost import XGBClassifier
# from lightgbm import LGBMClassifier
# from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier

#평가지표
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt



#모델 훈련 함수
def train_models(X_train, y_train):
    models = {
        # "XGBClassifier": XGBClassifier(),
        # "LGBMClassifier": LGBMClassifier(),
        # "RandomForestClassifier": RandomForestClassifier(),
        "CatBoostClassifier": CatBoostClassifier(verbose=0)  # verbose=0으로 설정하여 학습 중 메시지 출력을 최소화
    }

    for name, model in models.items():
        model.fit(X_train, y_train)
        models[name] = model

    return models

# %%
# pip install catboost

# %%
#train, val 시각화 함수
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 결과 시각화 함수
def evaluate_models(models, X_train, y_train, X_val, y_val):
    max_name_length = max([len(name) for name in models.keys()]) + 1  # 최대 모델 이름 길이 계산

    print("Model Performance Evaluation:\n")
    header = f"{'Model'.ljust(max_name_length)}\tTrain Accuracy\tVal Accuracy\tTrain F1\tVal F1"
    print(header)
    print("-" * len(header))

    for name, model in models.items():
        pred_train = model.predict(X_train)
        pred_val = model.predict(X_val)

        accuracy_train = accuracy_score(y_train, pred_train)
        accuracy_val = accuracy_score(y_val, pred_val)
        f1_train = f1_score(y_train, pred_train, average='macro')
        f1_val = f1_score(y_val, pred_val, average='macro')

        print(f"{name.ljust(max_name_length)}\t{accuracy_train:.4f}\t\t{accuracy_val:.4f}\t\t{f1_train:.4f}\t\t{f1_val:.4f}")

# %%
#모델 test 평가 함수
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

# train, val 시각화 함수
def plot_accuracy_for_models(models, X_train, y_train, X_val, y_val):
    # 모델별 정확도 저장을 위한 리스트
    train_accuracy_list = []
    val_accuracy_list = []
    model_names = []

    # 각 모델별로 정확도 계산
    for name, model in models.items():
        model.fit(X_train, y_train)
        train_pred = model.predict(X_train)
        val_pred = model.predict(X_val)

        train_accuracy = accuracy_score(y_train, train_pred)
        val_accuracy = accuracy_score(y_val, val_pred)

        train_accuracy_list.append(train_accuracy)
        val_accuracy_list.append(val_accuracy)
        model_names.append(name)

    # 선형 그래프로 정확도 결과 시각화
    plt.figure(figsize=(15, 7))
    plt.plot(model_names, train_accuracy_list, marker='o', label='Training Accuracy')
    plt.plot(model_names, val_accuracy_list, marker='o', label='Validation Accuracy')

    plt.ylabel('Accuracy')
    plt.title('Training and Validation Accuracy for Different Models')
    plt.legend()

    plt.show()

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import precision_recall_curve, auc
from sklearn.preprocessing import label_binarize

# 전체
def plot_auc_pr_curve(models, X_val, y_val): 
    y_val_binarized = label_binarize(y_val, classes=np.unique(y_val))
    n_classes = y_val_binarized.shape[1]

    plt.figure(figsize=(10, 8))

    for name, model in models.items():
        if hasattr(model, "predict_proba"):
            probas_pred = model.predict_proba(X_val)
        else:  # 예를 들어 SVM과 같은 경우
            probas_pred = model.decision_function(X_val)

        for i in range(n_classes):
            precision, recall, _ = precision_recall_curve(y_val_binarized[:, i], probas_pred[:, i])
            auc_score = auc(recall, precision)
            plt.plot(recall, precision, label=f'{name} - Class {i} (AUC-PR = {auc_score:.2f})')

    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve for Different Models and Classes')
    plt.legend()
    plt.show()

# %%
# model 1개
def plot_auc_pr_curve_one(model_name, models, X_val, y_val, label_encoder = label_encoder_gu):
    y_val_binarized = label_binarize(y_val, classes=np.unique(y_val))
    n_classes = y_val_binarized.shape[1]

    model = models[model_name]
    
    plt.figure(figsize=(12, 10))  # 그래프 크기를 좀 더 크게 조정

    if hasattr(model, "predict_proba"):
        probas_pred = model.predict_proba(X_val)
    else:  # 예를 들어 SVM과 같은 경우
        probas_pred = model.decision_function(X_val)

    for i in range(n_classes):
        precision, recall, _ = precision_recall_curve(y_val_binarized[:, i], probas_pred[:, i])
        auc_score = auc(recall, precision)
        original_class = label_encoder.inverse_transform([i])[0]
        plt.plot(recall, precision, label=f'{original_class} (AUC-PR = {auc_score:.2f})')

    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title(f'Precision-Recall Curve for {model_name}')
    
    # 범례를 아래로 옮기기
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=2)
    plt.tight_layout()
    plt.show()

# %%
#모델 훈련
import matplotlib.pyplot as plt

# 모델 test 평가 함수
def evaluate_models_on_test(models, X_test, y_test):
    max_name_length = max([len(name) for name in models.keys()]) + 1  # 최대 모델 이름 길이 계산

    print("Model Test Performance Evaluation:\n")
    header = f"{'Model'.ljust(max_name_length)}\tTest Accuracy\t\tTest F1-Score"
    print(header)
    print("-------------------------------------------------------------------------------------")

    for name, model in models.items():
        pred_test = model.predict(X_test)

        accuracy_test = accuracy_score(y_test, pred_test)
        f1_score_test = f1_score(y_test, pred_test, average='macro')

        print(f"{name.ljust(max_name_length)}\t{accuracy_test:.4f}\t\t{f1_score_test:.4f}")

# %%
#모델 훈련
models = train_models(X_train, y_train)

# %%
#모델 성능평가
evaluate_models(models, X_train, y_train, X_val, y_val)
# Out:
# Model Performance Evaluation:
#
# Model              	Train Accuracy	Val Accuracy	Train F1	Val F1
# ---------------------------------------------------------------
# CatBoostClassifier 	0.9473		0.6547		0.9474		0.3383

# %%
plot_auc_pr_curve_one('CatBoostClassifier', models, X_val, y_val)

# %%
#모델 test평가
evaluate_models_on_test(models, X_test, y_test)
# Out:
# Model Test Performance Evaluation:
#
# Model              	Test Accuracy		Test F1-Score
# -------------------------------------------------------------------------------------
# CatBoostClassifier 	0.6602		0.3226

# %%
plot_auc_pr_curve_one('CatBoostClassifier', models, X_test, y_test)
